# %% [markdown]
# # **Feature Extraction**

# %%
import librosa
import os
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Using mfcc**

# %% [markdown]
# #### The shape of each matrix is (13,351)

# %% [markdown]
# The choice of the number of frames (350) was based on the stability each could give, the full explanation is on the report

# %% [markdown]
# ### Functions to extract mfcc features

# %%
# Function to calculate MFCCs for a single audio file
def calculate_mfccs(audio_path, n_mfcc, n_frames, target_shape=(13,751)):
    # Load the audio file
    y, sr = librosa.load(audio_path, sr=None)
    # Calculate MFCCs
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc, hop_length=int(len(y) / n_frames))

    # Truncate to achieve the target shape - there are some cases where the matrix shape is (n_mfcc,752)
    if mfccs.shape[1] > target_shape[1]:
        mfccs = mfccs[:, :target_shape[1]]

    return mfccs

# %%
# Main processing function
def process_audio_files(base_dir, n_mfccs, n_frames):
    # Define the mfcc directory name based on the number of mfccs
    mfcc_dir_suffix = f'_mfccs_{n_mfccs}'

    # Iterate over each fold
    for i in range(1, 11):  # Assuming there are 10 folds
        original_fold_path = os.path.join(base_dir, f'fold{i}_4sec')
        mfcc_fold_path = os.path.join(base_dir, f'fold{i}_4sec{mfcc_dir_suffix}')

        # Create the mfcc directory if it doesn't exist
        if not os.path.exists(mfcc_fold_path):
            os.makedirs(mfcc_fold_path)

        # Check if the original fold directory exists
        if not os.path.isdir(original_fold_path):
            print(f"Directory {original_fold_path} does not exist.")
            continue

        # Iterate over each file in the original fold directory
        for audio_file in os.listdir(original_fold_path):
            if audio_file.lower().endswith('.wav'):
                audio_path = os.path.join(original_fold_path, audio_file)
                # Calculate MFCCs with the specified number of coefficients
                mfccs = calculate_mfccs(audio_path, n_mfccs, n_frames)
                print(mfccs.shape)
                # Save the MFCCs to the new directory
                np.save(os.path.join(mfcc_fold_path, audio_file.replace('.wav', f'_mfcc{n_mfccs}.npy')), mfccs)
                print(f"Processed and stored MFCCs for {audio_file} in {mfcc_fold_path}")

# %%
input_path = "/content/drive/MyDrive/UrbanSound8K/audio"

# %% [markdown]
# ### Number of coeffiecients by default = 13

# %%
process_audio_files(input_path, 13, 750)
# Out:
# Streaming output truncated to the last 5000 lines.
# (13, 751)
# Processed and stored MFCCs for 62566-5-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 50413-4-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 50885-3-0-4.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 50413-4-0-3.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 60846-0-0-1.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71173-2-0-69.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 72259-1-10-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 62566-5-0-1.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 65381-3-0-3.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 62566-5-0-3.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 62566-5-1-1.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 62566-5-2-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 60846-0-0-2.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 72259-1-9-4.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 72259-1-0-3.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71439-1-3-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 72259-1-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 72259-1-0-5.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71173-2-0-71.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71173-2-0-24.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71173-2-0-21.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 72259-1-7-7.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-3-2.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71173-2-0-103.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-1-2.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-2-1.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-1-5.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-1-3.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 43803-1-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 72259-1-7-17.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 6508-9-1-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 72259-1-3-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-3-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 72259-1-0-2.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-3-1.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71439-1-2-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71173-2-0-17.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-5-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-4-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 60846-0-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 6508-9-0-1.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 39533-4-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 39533-4-1-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 43787-3-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 46391-1-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 49312-2-0-10.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 46391-1-1-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71086-4-1-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 66587-3-1-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71171-4-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 65472-1-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 65381-3-0-7.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 71086-4-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 6508-9-0-4.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 26184-5-0-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 23219-5-0-8.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 23219-5-1-2.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 26184-5-4-1.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 23219-5-0-9.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 26177-1-2-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 34872-3-0-1.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 34872-3-0-2.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 43787-3-1-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 37869-3-3-0.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 36263-9-0-13.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 36263-9-0-2.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 36263-9-0-12.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 29937-3-0-6.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 31150-2-0-2.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for 34771-3-0-4.wav in /content/drive/MyDrive/UrbanSound8K/audio/fold5_4sec_mfccs_13
# (13, 751)
# Processed and stored MFCCs for